# %% [markdown]
# # Simulations Episode Scraper Match Downloader

# %% [markdown]
# From Kaggle user robga: https://www.kaggle.com/robga/simulations-episode-scraper-match-downloader
#
# This notebook downloads episodes using Kaggle's GetEpisodeReplay API and the [Meta Kaggle](https://www.kaggle.com/kaggle/meta-kaggle) dataset.
#
# Meta Kaggle is refreshed daily, and sometimes fails a daily refresh. That's OK, Goose keeps well for 24hr.
#
# Why download replays?
# - Train your ML/RL model
# - Inspect the performance of yours and others agents
# - To add to your ever growing json collection
#
# Only one scraping strategy is implemented: For each top scoring submission, download all missing matches, move on to next submission.
#
# Other scraping strategies can be implemented, but not here. Like download max X matches per submission or per team per day, or ignore certain teams or ignore where some scores < X, or only download some teams.
#
# Please let me know of any bugs. It's new, and my goose may be cooked.
#
# Todo:
# - Add teamid's once meta kaggle add them (a few days away)

# %%
import pandas as pd
import numpy as np
import os
import requests
import json
import datetime
import time
import glob
import collections

global num_api_calls_today
num_api_calls_today = 0

# %%
## You should configure these to your needs. Choose one of ...
# 'hungry-geese', 'rock-paper-scissors', santa-2020', 'halite', 'google-football'
COMP = 'hungry-geese'
MAX_CALLS_PER_DAY = 3300
LOWEST_SCORE_THRESH = 1000

# %%
META = "metadata/"
MATCH_DIR = 'data/'
base_url = "https://www.kaggle.com/requests/EpisodeService/"
get_url = base_url + "GetEpisodeReplay"
BUFFER = 1
COMPETITIONS = {
    'hungry-geese': 25401,
    'rock-paper-scissors': 22838,
    'santa-2020': 24539,
    'halite': 18011,
    'google-football': 21723
}

# %%
# Load Episodes
episodes_df = pd.read_csv(META + "Episodes.csv")

# Load EpisodeAgents
epagents_df = pd.read_csv(META + "EpisodeAgents.csv")

print(f'Episodes.csv: {len(episodes_df)} rows before filtering.')
print(f'EpisodeAgents.csv: {len(epagents_df)} rows before filtering.')

episodes_df = episodes_df[episodes_df.CompetitionId == COMPETITIONS[COMP]] 
epagents_df = epagents_df[epagents_df.EpisodeId.isin(episodes_df.Id)]

print(f'Episodes.csv: {len(episodes_df)} rows after filtering for {COMP}.')
print(f'EpisodeAgents.csv: {len(epagents_df)} rows after filtering for {COMP}.')
# Out:
# Episodes.csv: 19323843 rows before filtering.
# EpisodeAgents.csv: 42510886 rows before filtering.
# Episodes.csv: 108525 rows after filtering for hungry-geese.
# EpisodeAgents.csv: 434100 rows after filtering for hungry-geese.

# %%
# Prepare dataframes
episodes_df = episodes_df.set_index(['Id'])
episodes_df['CreateTime'] = pd.to_datetime(episodes_df['CreateTime'])
episodes_df['EndTime'] = pd.to_datetime(episodes_df['EndTime'])

epagents_df.fillna(0, inplace=True)
epagents_df = epagents_df.sort_values(by=['Id'], ascending=False)

# %%
# Get top scoring submissions
max_df = (epagents_df.sort_values(by=['EpisodeId'], ascending=False).groupby('SubmissionId').head(1).drop_duplicates().reset_index(drop=True))
max_df = max_df[max_df.UpdatedScore>=LOWEST_SCORE_THRESH]
max_df = pd.merge(left=episodes_df, right=max_df, left_on='Id', right_on='EpisodeId')
sub_to_score_top = pd.Series(max_df.UpdatedScore.values,index=max_df.SubmissionId).to_dict()
print(f'{len(sub_to_score_top)} submissions with score over {LOWEST_SCORE_THRESH}')
# Out:
# 1127 submissions with score over 1000

# %%
# Get episodes for these submissions
sub_to_episodes = collections.defaultdict(list)
for key, value in sorted(sub_to_score_top.items(), key=lambda kv: kv[1], reverse=True):
    eps = sorted(epagents_df[epagents_df['SubmissionId'].isin([key])]['EpisodeId'].values,reverse=True)
    sub_to_episodes[key] = eps
candidates = len(set([item for sublist in sub_to_episodes.values() for item in sublist]))
print(f'{candidates} episodes for these {len(sub_to_score_top)} submissions')
# Out:
# 36912 episodes for these 1127 submissions

# %%
all_files = []
for root, dirs, files in os.walk(MATCH_DIR, topdown=False):
    all_files.extend(files)
seen_episodes = [int(f.split('.')[0]) for f in all_files 
                      if '.' in f and f.split('.')[0].isdigit() and f.split('.')[1] == 'json']
remaining = np.setdiff1d([item for sublist in sub_to_episodes.values() for item in sublist],seen_episodes)
print(f'{len(remaining)} of these {candidates} episodes not yet saved')
print('Total of {} games in existing library'.format(len(seen_episodes)))
# Out:
# 33911 of these 36912 episodes not yet saved
# Total of 3001 games in existing library

# %%
def create_info_json(epid):
    
    create_seconds = int((episodes_df[episodes_df.index == epid]['CreateTime'].values[0]).item()/1e9)
    end_seconds = int((episodes_df[episodes_df.index == epid]['CreateTime'].values[0]).item()/1e9)

    agents = []
    for index, row in epagents_df[epagents_df['EpisodeId'] == epid].sort_values(by=['Index']).iterrows():
        agent = {
            "id": int(row["Id"]),
            "state": int(row["State"]),
            "submissionId": int(row['SubmissionId']),
            "reward": int(row['Reward']),
            "index": int(row['Index']),
            "initialScore": float(row['InitialScore']),
            "initialConfidence": float(row['InitialConfidence']),
            "updatedScore": float(row['UpdatedScore']),
            "updatedConfidence": float(row['UpdatedConfidence']),
            "teamId": int(99999)
        }
        agents.append(agent)

    info = {
        "id": int(epid),
        "competitionId": int(COMPETITIONS[COMP]),
        "createTime": {
            "seconds": int(create_seconds)
        },
        "endTime": {
            "seconds": int(end_seconds)
        },
        "agents": agents
    }

    return info

def saveEpisode(epid):
    # request
    re = requests.post(get_url, json = {"EpisodeId": int(epid)})
        
    # save replay
    with open(MATCH_DIR + '{}.json'.format(epid), 'w') as f:
        f.write(re.json()['result']['replay'])

    # save match info
    info = create_info_json(epid)
    with open(MATCH_DIR +  '{}_info.json'.format(epid), 'w') as f:
        json.dump(info, f)

# %%
r = BUFFER;

start_time = datetime.datetime.now()
se=0
for key, value in sorted(sub_to_score_top.items(), key=lambda kv: kv[1], reverse=True):
    if num_api_calls_today<=MAX_CALLS_PER_DAY:
        print('')
        remaining = sorted(np.setdiff1d(sub_to_episodes[key],seen_episodes), reverse=True)
        print(f'submission={key}, LB={"{:.0f}".format(value)}, matches={len(set(sub_to_episodes[key]))}, still to save={len(remaining)}')
        
        for epid in remaining:
            if epid not in seen_episodes and num_api_calls_today<=MAX_CALLS_PER_DAY:
                saveEpisode(epid); 
                r+=1;
                se+=1
                try:
                    size = os.path.getsize(MATCH_DIR+'{}.json'.format(epid)) / 1e6
                    print(str(num_api_calls_today) + f': saved episode #{epid}')
                    seen_episodes.append(epid)
                    num_api_calls_today+=1
                except:
                    print('  file {}.json did not seem to save'.format(epid))    
                if r > (datetime.datetime.now() - start_time).seconds:
                    time.sleep( r - (datetime.datetime.now() - start_time).seconds)
            if num_api_calls_today >= (min(3600,MAX_CALLS_PER_DAY)):
                break
print('')
print(f'Episodes saved: {se}')
# Out:
# submission=19711300, LB=1240, matches=21, still to save=0
#
# submission=19708538, LB=1202, matches=24, still to save=0
#
# submission=19722457, LB=1196, matches=16, still to save=0
#
# submission=19652367, LB=1176, matches=40, still to save=0
#
# submission=19719024, LB=1171, matches=17, still to save=0
#
# submission=19721626, LB=1161, matches=16, still to save=0
#
# submission=19722523, LB=1158, matches=15, still to save=0
#
# submission=19711076, LB=1154, matches=21, still to save=0
#
# submission=19681519, LB=1153, matches=32, still to save=0
#
# submission=19533620, LB=1148, matches=78, still to save=0
#
# submission=19722219, LB=1148, matches=16, still to save=0
#
# submission=19519164, LB=1140, matches=79, still to save=0
#
# submission=19517799, LB=1138, matches=89, still to save=0
#
# submission=19487408, LB=1137, matches=94, still to save=0
#
# submission=19471900, LB=1136, matches=95, still to save=0
#
# submission=19719678, LB=1135, matches=18, still to save=0
#
# submission=19681376, LB=1135, matches=30, still to save=0
#
# submission=19514384, LB=1133, matches=70, still to save=0
#
# submission=19711133, LB=1132, matches=22, still to save=0
#
# submission=19530996, LB=1132, matches=75, still to save=0
#
# submission=19636110, LB=1129, matches=49, still to save=0
#
# submission=19483589, LB=1128, matches=88, still to save=0
#
# submission=19476680, LB=1128, matches=76, still to save=0
#
# submission=19705803, LB=1127, matches=24, still to save=0
#
# submission=19613348, LB=1127, matches=54, still to save=0
#
# submission=19721013, LB=1123, matches=17, still to save=0
#
# submission=19498585, LB=1122, matches=95, still to save=0
#
# submission=19635284, LB=1122, matches=43, still to save=0
#
# submission=19654223, LB=1122, matches=37, still to save=0
#
# submission=19480854, LB=1119, matches=120, still to save=0
#
# submission=19715423, LB=1119, matches=19, still to save=0
#
# submission=19469841, LB=1118, matches=100, still to save=0
#
# submission=19701978, LB=1117, matches=28, still to save=0
#
# submission=19469817, LB=1115, matches=105, still to save=0
#
# submission=19537563, LB=1115, matches=68, still to save=0
#
# submission=19459423, LB=1114, matches=99, still to save=0
#
# submission=19703409, LB=1113, matches=26, still to save=0
#
# submission=19716078, LB=1112, matches=19, still to save=0
#
# submission=19691159, LB=1112, matches=36, still to save=0
#
# submission=19498640, LB=1111, matches=105, still to save=0
#
# submission=19614537, LB=1110, matches=65, still to save=0
#
# submission=19590854, LB=1110, matches=53, still to save=0
#
# submission=19614085, LB=1110, matches=47, still to save=0
#
# submission=19705401, LB=1109, matches=26, still to save=0
#
# submission=19522207, LB=1109, matches=72, still to save=0
#
# submission=19633549, LB=1109, matches=45, still to save=0
#
# submission=19458246, LB=1109, matches=92, still to save=0
#
# submission=19472912, LB=1108, matches=97, still to save=0
#
# submission=19690963, LB=1107, matches=35, still to save=0
#
# submission=19558766, LB=1106, matches=67, still to save=0
#
# submission=19639153, LB=1103, matches=51, still to save=0
#
# submission=19483380, LB=1103, matches=95, still to save=0
#
# submission=19641391, LB=1102, matches=53, still to save=0
#
# submission=19506800, LB=1102, matches=87, still to save=0
#
# submission=19556071, LB=1102, matches=70, still to save=0
#
# submission=19692796, LB=1101, matches=27, still to save=0
#
# submission=19527395, LB=1101, matches=88, still to save=0
#
# submission=19484141, LB=1100, matches=90, still to save=0
#
# submission=19710687, LB=1100, matches=22, still to save=0
#
# submission=19504303, LB=1100, matches=88, still to save=0
#
# submission=19559130, LB=1100, matches=79, still to save=0
#
# submission=19517806, LB=1099, matches=101, still to save=53
# 3001: saved episode #18122483
# 3002: saved episode #18079007
# 3003: saved episode #18078381
# 3004: saved episode #18067742
# 3005: saved episode #18052733
# 3006: saved episode #18041468
# 3007: saved episode #17967665
# 3008: saved episode #17961399
# 3009: saved episode #17947644
# 3010: saved episode #17921358
# 3011: saved episode #17840734
# 3012: saved episode #17808294
# 3013: saved episode #17662050
# 3014: saved episode #17549840
# 3015: saved episode #17519273
# 3016: saved episode #17509916
# 3017: saved episode #17441405
# 3018: saved episode #17440160
# 3019: saved episode #17410277
# 3020: saved episode #17408419
# 3021: saved episode #17370451
# 3022: saved episode #17361742
# 3023: saved episode #17358009
# 3024: saved episode #17288257
# 3025: saved episode #17165849
# 3026: saved episode #17134010
# 3027: saved episode #17074119
# 3028: saved episode #17024859
# 3029: saved episode #16985593
# 3030: saved episode #16922616
# 3031: saved episode #16913882
# 3032: saved episode #16859029
# 3033: saved episode #16854043
# 3034: saved episode #16786076
# 3035: saved episode #16779224
# 3036: saved episode #16740566
# 3037: saved episode #16739945
# 3038: saved episode #16736205
# 3039: saved episode #16735587
# 3040: saved episode #16714394
# 3041: saved episode #16711899
# 3042: saved episode #16711275
# 3043: saved episode #16710653
# 3044: saved episode #16710031
# 3045: saved episode #16709409
# 3046: saved episode #16708785
# 3047: saved episode #16708163
# 3048: saved episode #16707542
# 3049: saved episode #16706920
# 3050: saved episode #16706298
# 3051: saved episode #16705676
# 3052: saved episode #16705053
# 3053: saved episode #16704438
#
# submission=19627715, LB=1099, matches=53, still to save=48
# 3054: saved episode #19428806
# 3055: saved episode #19426034
# 3056: saved episode #19423673
# 3057: saved episode #19420140
# 3058: saved episode #19413308
# 3059: saved episode #19412992
# 3060: saved episode #19411610
# 3061: saved episode #19409294
# 3062: saved episode #19336439
# 3063: saved episode #19326092
# 3064: saved episode #19292305
# 3065: saved episode #19283343
# 3066: saved episode #19208173
# 3067: saved episode #19130222
# 3068: saved episode #19108858
# 3069: saved episode #19034408
# 3070: saved episode #18997901
# 3071: saved episode #18930439
# 3072: saved episode #18889787
# 3073: saved episode #18845715
# 3074: saved episode #18778945
# 3075: saved episode #18754839
# 3076: saved episode #18719099
# 3077: saved episode #18694351
# 3078: saved episode #18668214
# 3079: saved episode #18602270
# 3080: saved episode #18547984
# 3081: saved episode #18517883
# 3082: saved episode #18473327
# 3083: saved episode #18449518
# 3084: saved episode #18394384
# 3085: saved episode #18386857
# 3086: saved episode #18349258
# 3087: saved episode #18334847
# 3088: saved episode #18313542
# 3089: saved episode #18309166
# 3090: saved episode #18308540
# 3091: saved episode #18307913
# 3092: saved episode #18307284
# 3093: saved episode #18306652
# 3094: saved episode #18306021
# 3095: saved episode #18305394
# 3096: saved episode #18304768
# 3097: saved episode #18304142
# 3098: saved episode #18303516
# 3099: saved episode #18302889
# 3100: saved episode #18302260
# 3101: saved episode #18301646
#
# submission=19469854, LB=1097, matches=101, still to save=81
# 3102: saved episode #19426786
# 3103: saved episode #19422880
# 3104: saved episode #19415781
# 3105: saved episode #19414595
# 3106: saved episode #19408690
# 3107: saved episode #19408666
# 3108: saved episode #19408225
# 3109: saved episode #19368151
# 3110: saved episode #19335754
# 3111: saved episode #19309536
# 3112: saved episode #19237802
# 3113: saved episode #19157805
# 3114: saved episode #19079204
# 3115: saved episode #19021323
# 3116: saved episode #18964179
# 3117: saved episode #18878783
# 3118: saved episode #18718402
# 3119: saved episode #18680589
# 3120: saved episode #18596004
# 3121: saved episode #18532318
# 3122: saved episode #18454530
# 3123: saved episode #18406916
# 3124: saved episode #18337351
# 3125: saved episode #18263445
# 3126: saved episode #18187638
# 3127: saved episode #18110273
# 3128: saved episode #18030220
# 3129: saved episode #17895076
# 3130: saved episode #17817019
# 3131: saved episode #17749717
# 3132: saved episode #17735004
# 3133: saved episode #17672015
# 3134: saved episode #17669521
# 3135: saved episode #17583488
# 3136: saved episode #17506800
# 3137: saved episode #17387875
# 3138: saved episode #17310710
# 3139: saved episode #17151491
# 3140: saved episode #17125888
# 3141: saved episode #17056039
# 3142: saved episode #16962524
# 3143: saved episode #16941317
# 3144: saved episode #16910764
# 3145: saved episode #16841576
# 3146: saved episode #16835344
# 3147: saved episode #16806975
# 3148: saved episode #16760512
# 3149: saved episode #16752410
# 3150: saved episode #16666472
# 3151: saved episode #16627864
# 3152: saved episode #16565620
# 3153: saved episode #16561892
# 3154: saved episode #16474746
# 3155: saved episode #16433674
# 3156: saved episode #16429319
# 3157: saved episode #16355901
# 3158: saved episode #16336318
# 3159: saved episode #16316734
# 3160: saved episode #16294992
# 3161: saved episode #16256455
# 3162: saved episode #16243398
# 3163: saved episode #16240291
# 3164: saved episode #16235325
# 3165: saved episode #16177523
# 3166: saved episode #16149548
# 3167: saved episode #16115980
# 3168: saved episode #16097957
# 3169: saved episode #16039597
# 3170: saved episode #15999269
# 3171: saved episode #15989964
# 3172: saved episode #15983139
# 3173: saved episode #15982519
# 3174: saved episode #15981899
# 3175: saved episode #15981279
# 3176: saved episode #15980659
# 3177: saved episode #15980039
# 3178: saved episode #15979420
# 3179: saved episode #15978800
# 3180: saved episode #15978180
# 3181: saved episode #15977558
# 3182: saved episode #15976944
#
# submission=19492891, LB=1097, matches=94, still to save=67
# 3183: saved episode #19429122
# 3184: saved episode #19427913
# 3185: saved episode #19426654
# 3186: saved episode #19422776
# 3187: saved episode #19418915
# 3188: saved episode #19417731
# 3189: saved episode #19414072
# 3190: saved episode #19412814
# 3191: saved episode #19385388
# 3192: saved episode #19304721
# 3193: saved episode #19274377
# 3194: saved episode #19246782
# 3195: saved episode #19193006
# 3196: saved episode #19117128
# 3197: saved episode #19036478
# 3198: saved episode #18937323
# 3199: saved episode #18870526
# 3200: saved episode #18785828
# 3201: saved episode #18730100
# 3202: saved episode #18659961
# 3203: saved episode #18213958
# 3204: saved episode #18159447
# 3205: saved episode #18079631
# 3206: saved episode #18023347
# 3207: saved episode #17933254
# 3208: saved episode #17845100
# 3209: saved episode #17701324
# 3210: saved episode #17585365
# 3211: saved episode #17519894
# 3212: saved episode #17462583
# 3213: saved episode #17334354
# 3214: saved episode #17318787
# 3215: saved episode #17210805
# 3216: saved episode #17156479
# 3217: saved episode #17134631
# 3218: saved episode #17117148
# 3219: saved episode #17091570
# 3220: saved episode #17074738
# 3221: saved episode #17001169
# 3222: saved episode #16952543
# 3223: saved episode #16881463
# 3224: saved episode #16852800
# 3225: saved episode #16794182
# 3226: saved episode #16764256
# 3227: saved episode #16759268
# 3228: saved episode #16757398
# 3229: saved episode #16721248
# 3230: saved episode #16654648
# 3231: saved episode #16640942
# 3232: saved episode #16510841
# 3233: saved episode #16465414
# 3234: saved episode #16457950
# 3235: saved episode #16452349
# 3236: saved episode #16420598
# 3237: saved episode #16398805
# 3238: saved episode #16362123
# 3239: saved episode #16336324
# 3240: saved episode #16330113
# 3241: saved episode #16328251
# 3242: saved episode #16327313
# 3243: saved episode #16326691
# 3244: saved episode #16326070
# 3245: saved episode #16325448
# 3246: saved episode #16324827
# 3247: saved episode #16324203
# 3248: saved episode #16323577
# 3249: saved episode #16322964
#
# submission=19591782, LB=1097, matches=64, still to save=52
# 3250: saved episode #19428911
# 3251: saved episode #19428248
# 3252: saved episode #19428217
# 3253: saved episode #19426523
# 3254: saved episode #19422717
# 3255: saved episode #19421338
# 3256: saved episode #19418414
# 3257: saved episode #19416659
# 3258: saved episode #19414616
# 3259: saved episode #19411306
# 3260: saved episode #19392284
# 3261: saved episode #19384698
# 3262: saved episode #19381260
# 3263: saved episode #19303335
# 3264: saved episode #19221258
# 3265: saved episode #19209543
# 3266: saved episode #19126773
# 3267: saved episode #18992397
# 3268: saved episode #18958664
# 3269: saved episode #18929060
# 3270: saved episode #18906326
# 3271: saved episode #18832632
# 3272: saved episode #18792017
# 3273: saved episode #18713598
# 3274: saved episode #18675085
# 3275: saved episode #18633843
# 3276: saved episode #18587213
# 3277: saved episode #18511601
# 3278: saved episode #18448886
# 3279: saved episode #18378704
# 3280: saved episode #18317305
# 3281: saved episode #18282216
# 3282: saved episode #18252799
# 3283: saved episode #18252170
# 3284: saved episode #18243402
# 3285: saved episode #18188268
# 3286: saved episode #18173857
# 3287: saved episode #18044604
# 3288: saved episode #18003941
# 3289: saved episode #17920113
# 3290: saved episode #17881946
# 3291: saved episode #17861956
# 3292: saved episode #17861332
# 3293: saved episode #17860705
# 3294: saved episode #17860081
# 3295: saved episode #17859455
# 3296: saved episode #17858829
# 3297: saved episode #17858203
# 3298: saved episode #17857577
# 3299: saved episode #17856951
#
# submission=19477534, LB=1096, matches=118, still to save=87
# 3300: saved episode #19426622
#
# Episodes saved: 300
