# %% [markdown]
# # Simulations Episode Scraper Match Downloader

# %% [markdown]
# From Kaggle user robga: https://www.kaggle.com/robga/simulations-episode-scraper-match-downloader
#
# This notebook downloads episodes using Kaggle's GetEpisodeReplay API and the [Meta Kaggle](https://www.kaggle.com/kaggle/meta-kaggle) dataset.
#
# Meta Kaggle is refreshed daily, and sometimes fails a daily refresh. That's OK, Goose keeps well for 24hr.
#
# Why download replays?
# - Train your ML/RL model
# - Inspect the performance of yours and others agents
# - To add to your ever growing json collection
#
# Only one scraping strategy is implemented: For each top scoring submission, download all missing matches, move on to next submission.
#
# Other scraping strategies can be implemented, but not here. Like download max X matches per submission or per team per day, or ignore certain teams or ignore where some scores < X, or only download some teams.
#
# Please let me know of any bugs. It's new, and my goose may be cooked.
#
# Todo:
# - Add teamid's once meta kaggle add them (a few days away)

# %%
import pandas as pd
import numpy as np
import os
import requests
import json
import datetime
import time
import glob
import collections

global num_api_calls_today
num_api_calls_today = 0

# %%
## You should configure these to your needs. Choose one of ...
# 'hungry-geese', 'rock-paper-scissors', santa-2020', 'halite', 'google-football'
COMP = 'hungry-geese'
MAX_CALLS_PER_DAY = 3400
LOWEST_SCORE_THRESH = 1000

# %%
META = "metadata/"
MATCH_DIR = 'data/'
base_url = "https://www.kaggle.com/requests/EpisodeService/"
get_url = base_url + "GetEpisodeReplay"
BUFFER = 1
COMPETITIONS = {
    'hungry-geese': 25401,
    'rock-paper-scissors': 22838,
    'santa-2020': 24539,
    'halite': 18011,
    'google-football': 21723
}

# %%
# Load Episodes
episodes_df = pd.read_csv(META + "Episodes.csv")

# Load EpisodeAgents
epagents_df = pd.read_csv(META + "EpisodeAgents.csv")

print(f'Episodes.csv: {len(episodes_df)} rows before filtering.')
print(f'EpisodeAgents.csv: {len(epagents_df)} rows before filtering.')

episodes_df = episodes_df[episodes_df.CompetitionId == COMPETITIONS[COMP]] 
epagents_df = epagents_df[epagents_df.EpisodeId.isin(episodes_df.Id)]

print(f'Episodes.csv: {len(episodes_df)} rows after filtering for {COMP}.')
print(f'EpisodeAgents.csv: {len(epagents_df)} rows after filtering for {COMP}.')
# Out:
# Episodes.csv: 19335777 rows before filtering.
# EpisodeAgents.csv: 42549950 rows before filtering.
# Episodes.csv: 116112 rows after filtering for hungry-geese.
# EpisodeAgents.csv: 464448 rows after filtering for hungry-geese.

# %%
# Prepare dataframes
episodes_df = episodes_df.set_index(['Id'])
episodes_df['CreateTime'] = pd.to_datetime(episodes_df['CreateTime'])
episodes_df['EndTime'] = pd.to_datetime(episodes_df['EndTime'])

epagents_df.fillna(0, inplace=True)
epagents_df = epagents_df.sort_values(by=['Id'], ascending=False)

# %%
# Get top scoring submissions
max_df = (epagents_df.sort_values(by=['EpisodeId'], ascending=False).groupby('SubmissionId').head(1).drop_duplicates().reset_index(drop=True))
max_df = max_df[max_df.UpdatedScore>=LOWEST_SCORE_THRESH]
max_df = pd.merge(left=episodes_df, right=max_df, left_on='Id', right_on='EpisodeId')
sub_to_score_top = pd.Series(max_df.UpdatedScore.values,index=max_df.SubmissionId).to_dict()
print(f'{len(sub_to_score_top)} submissions with score over {LOWEST_SCORE_THRESH}')
# Out:
# 1195 submissions with score over 1000

# %%
# Get episodes for these submissions
sub_to_episodes = collections.defaultdict(list)
for key, value in sorted(sub_to_score_top.items(), key=lambda kv: kv[1], reverse=True):
    eps = sorted(epagents_df[epagents_df['SubmissionId'].isin([key])]['EpisodeId'].values,reverse=True)
    sub_to_episodes[key] = eps
candidates = len(set([item for sublist in sub_to_episodes.values() for item in sublist]))
print(f'{candidates} episodes for these {len(sub_to_score_top)} submissions')
# Out:
# 40357 episodes for these 1195 submissions

# %%
all_files = []
for root, dirs, files in os.walk(MATCH_DIR, topdown=False):
    all_files.extend(files)
seen_episodes = [int(f.split('.')[0]) for f in all_files 
                      if '.' in f and f.split('.')[0].isdigit() and f.split('.')[1] == 'json']
remaining = np.setdiff1d([item for sublist in sub_to_episodes.values() for item in sublist],seen_episodes)
print(f'{len(remaining)} of these {candidates} episodes not yet saved')
print('Total of {} games in existing library'.format(len(seen_episodes)))
# Out:
# 37056 of these 40357 episodes not yet saved
# Total of 3301 games in existing library

# %%
def create_info_json(epid):
    
    create_seconds = int((episodes_df[episodes_df.index == epid]['CreateTime'].values[0]).item()/1e9)
    end_seconds = int((episodes_df[episodes_df.index == epid]['CreateTime'].values[0]).item()/1e9)

    agents = []
    for index, row in epagents_df[epagents_df['EpisodeId'] == epid].sort_values(by=['Index']).iterrows():
        agent = {
            "id": int(row["Id"]),
            "state": int(row["State"]),
            "submissionId": int(row['SubmissionId']),
            "reward": int(row['Reward']),
            "index": int(row['Index']),
            "initialScore": float(row['InitialScore']),
            "initialConfidence": float(row['InitialConfidence']),
            "updatedScore": float(row['UpdatedScore']),
            "updatedConfidence": float(row['UpdatedConfidence']),
            "teamId": int(99999)
        }
        agents.append(agent)

    info = {
        "id": int(epid),
        "competitionId": int(COMPETITIONS[COMP]),
        "createTime": {
            "seconds": int(create_seconds)
        },
        "endTime": {
            "seconds": int(end_seconds)
        },
        "agents": agents
    }

    return info

def saveEpisode(epid):
    # request
    re = requests.post(get_url, json = {"EpisodeId": int(epid)})
        
    # save replay
    with open(MATCH_DIR + '{}.json'.format(epid), 'w') as f:
        f.write(re.json()['result']['replay'])

    # save match info
    info = create_info_json(epid)
    with open(MATCH_DIR +  '{}_info.json'.format(epid), 'w') as f:
        json.dump(info, f)

# %%
r = BUFFER;

start_time = datetime.datetime.now()
se=0
for key, value in sorted(sub_to_score_top.items(), key=lambda kv: kv[1], reverse=True):
    if num_api_calls_today<=MAX_CALLS_PER_DAY:
        print('')
        remaining = sorted(np.setdiff1d(sub_to_episodes[key],seen_episodes), reverse=True)
        print(f'submission={key}, LB={"{:.0f}".format(value)}, matches={len(set(sub_to_episodes[key]))}, still to save={len(remaining)}')
        
        for epid in remaining:
            if epid not in seen_episodes and num_api_calls_today<=MAX_CALLS_PER_DAY:
                saveEpisode(epid); 
                r+=1;
                se+=1
                try:
                    size = os.path.getsize(MATCH_DIR+'{}.json'.format(epid)) / 1e6
                    print(str(num_api_calls_today) + f': saved episode #{epid}')
                    seen_episodes.append(epid)
                    num_api_calls_today+=1
                except:
                    print('  file {}.json did not seem to save'.format(epid))    
                if r > (datetime.datetime.now() - start_time).seconds:
                    time.sleep( r - (datetime.datetime.now() - start_time).seconds)
            if num_api_calls_today >= (min(3600,MAX_CALLS_PER_DAY)):
                break
print('')
print(f'Episodes saved: {se}')
# Out:
# submission=19722457, LB=1254, matches=21, still to save=5
# 0: saved episode #19439530
# 1: saved episode #19437799
# 2: saved episode #19435628
# 3: saved episode #19433412
# 4: saved episode #19431254
#
# submission=19711300, LB=1249, matches=25, still to save=4
# 5: saved episode #19439896
# 6: saved episode #19437293
# 7: saved episode #19434473
# 8: saved episode #19431485
#
# submission=19719024, LB=1219, matches=23, still to save=5
# 9: saved episode #19439834
# 10: saved episode #19436450
# 11: saved episode #19435031
# 12: saved episode #19432326
# 13: saved episode #19430265
#
# submission=19721626, LB=1214, matches=21, still to save=4
# 14: saved episode #19439331
# 15: saved episode #19437018
# 16: saved episode #19433217
# 17: saved episode #19431031
#
# submission=19728229, LB=1214, matches=18, still to save=18
# 18: saved episode #19440001
# 19: saved episode #19438432
# 20: saved episode #19437048
# 21: saved episode #19435500
# 22: saved episode #19434440
# 23: saved episode #19434405
# 24: saved episode #19434074
# 25: saved episode #19434042
# 26: saved episode #19434012
# 27: saved episode #19433978
# 28: saved episode #19433946
# 29: saved episode #19433906
# 30: saved episode #19433870
# 31: saved episode #19433834
# 32: saved episode #19433800
# 33: saved episode #19433764
# 34: saved episode #19433730
# 35: saved episode #19433682
#
# submission=19708538, LB=1211, matches=28, still to save=3
# 36: saved episode #19440564
# 37: saved episode #19437760
# 38: saved episode #19434725
#
# submission=19725734, LB=1192, matches=20, still to save=20
# 39: saved episode #19440064
# 40: saved episode #19438000
# 41: saved episode #19435877
# 42: saved episode #19435668
# 43: saved episode #19433813
# 44: saved episode #19432052
# 45: saved episode #19432020
# 46: saved episode #19431988
# 47: saved episode #19431956
# 48: saved episode #19431924
# 49: saved episode #19431892
# 50: saved episode #19431860
# 51: saved episode #19431828
# 52: saved episode #19431796
# 53: saved episode #19431764
# 54: saved episode #19431730
# 55: saved episode #19431698
# 56: saved episode #19431666
# 57: saved episode #19431634
# 58: saved episode #19431588
#
# submission=19722219, LB=1190, matches=22, still to save=5
# 59: saved episode #19439567
# 60: saved episode #19437833
# 61: saved episode #19435736
# 62: saved episode #19433446
# 63: saved episode #19431220
#
# submission=19729286, LB=1177, matches=19, still to save=19
# 64: saved episode #19440469
# 65: saved episode #19438739
# 66: saved episode #19438067
# 67: saved episode #19436690
# 68: saved episode #19435190
# 69: saved episode #19435159
# 70: saved episode #19435118
# 71: saved episode #19435084
# 72: saved episode #19435050
# 73: saved episode #19435016
# 74: saved episode #19434981
# 75: saved episode #19434948
# 76: saved episode #19434916
# 77: saved episode #19434882
# 78: saved episode #19434850
# 79: saved episode #19434816
# 80: saved episode #19434780
# 81: saved episode #19434747
# 82: saved episode #19434670
#
# submission=19721013, LB=1166, matches=24, still to save=7
# 83: saved episode #19440107
# 84: saved episode #19438671
# 85: saved episode #19436082
# 86: saved episode #19434834
# 87: saved episode #19434367
# 88: saved episode #19431487
# 89: saved episode #19431473
#
# submission=19729402, LB=1160, matches=19, still to save=16
# 90: saved episode #19441071
# 91: saved episode #19437693
# 92: saved episode #19435252
# 93: saved episode #19435217
# 94: saved episode #19435183
# 95: saved episode #19435149
# 96: saved episode #19435115
# 97: saved episode #19435081
# 98: saved episode #19435047
# 99: saved episode #19435013
# 100: saved episode #19434978
# 101: saved episode #19434945
# 102: saved episode #19434913
# 103: saved episode #19434879
# 104: saved episode #19434847
# 105: saved episode #19434800
#
# submission=19733354, LB=1157, matches=18, still to save=16
# 106: saved episode #19438958
# 107: saved episode #19438924
# 108: saved episode #19438891
# 109: saved episode #19438858
# 110: saved episode #19438825
# 111: saved episode #19438790
# 112: saved episode #19438757
# 113: saved episode #19438722
# 114: saved episode #19438687
# 115: saved episode #19438653
# 116: saved episode #19438620
# 117: saved episode #19438586
# 118: saved episode #19438552
# 119: saved episode #19438519
# 120: saved episode #19438485
# 121: saved episode #19438471
#
# submission=19711076, LB=1156, matches=27, still to save=4
# 122: saved episode #19439807
# 123: saved episode #19439165
# 124: saved episode #19436414
# 125: saved episode #19431746
#
# submission=19727623, LB=1155, matches=19, still to save=19
# 126: saved episode #19440445
# 127: saved episode #19439634
# 128: saved episode #19438003
# 129: saved episode #19436515
# 130: saved episode #19435701
# 131: saved episode #19434596
# 132: saved episode #19433667
# 133: saved episode #19433635
# 134: saved episode #19433601
# 135: saved episode #19433567
# 136: saved episode #19433533
# 137: saved episode #19433497
# 138: saved episode #19433464
# 139: saved episode #19433430
# 140: saved episode #19433398
# 141: saved episode #19433366
# 142: saved episode #19433334
# 143: saved episode #19433302
# 144: saved episode #19433256
#
# submission=19681519, LB=1153, matches=36, still to save=3
# 145: saved episode #19438320
# 146: saved episode #19434893
# 147: saved episode #19430678
#
# submission=19533620, LB=1151, matches=84, still to save=2
# 148: saved episode #19435694
# 149: saved episode #19431742
#
# submission=19722523, LB=1149, matches=21, still to save=3
# 150: saved episode #19440076
# 151: saved episode #19432259
# 152: saved episode #19430782
#
# submission=19652367, LB=1149, matches=46, still to save=4
# 153: saved episode #19440471
# 154: saved episode #19438099
# 155: saved episode #19433121
# 156: saved episode #19430638
#
# submission=19517799, LB=1143, matches=92, still to save=2
# 157: saved episode #19436307
# 158: saved episode #19432288
#
# submission=19711133, LB=1142, matches=28, still to save=3
# 159: saved episode #19436621
# 160: saved episode #19433549
# 161: saved episode #19430522
#
# submission=19716078, LB=1141, matches=28, still to save=6
# 162: saved episode #19440110
# 163: saved episode #19436694
# 164: saved episode #19433644
# 165: saved episode #19433503
# 166: saved episode #19433147
# 167: saved episode #19430641
#
# submission=19710687, LB=1141, matches=29, still to save=6
# 168: saved episode #19439592
# 169: saved episode #19437047
# 170: saved episode #19433875
# 171: saved episode #19433479
# 172: saved episode #19433112
# 173: saved episode #19430225
#
# submission=19636110, LB=1135, matches=52, still to save=2
# 174: saved episode #19440097
# 175: saved episode #19436987
#
# submission=19487408, LB=1134, matches=98, still to save=2
# 176: saved episode #19435293
# 177: saved episode #19430807
#
# submission=19725921, LB=1134, matches=19, still to save=19
# 178: saved episode #19439699
# 179: saved episode #19437655
# 180: saved episode #19437289
# 181: saved episode #19435362
# 182: saved episode #19433499
# 183: saved episode #19432149
# 184: saved episode #19432116
# 185: saved episode #19432083
# 186: saved episode #19432051
# 187: saved episode #19432019
# 188: saved episode #19431987
# 189: saved episode #19431955
# 190: saved episode #19431923
# 191: saved episode #19431891
# 192: saved episode #19431859
# 193: saved episode #19431827
# 194: saved episode #19431795
# 195: saved episode #19431763
# 196: saved episode #19431750
#
# submission=19530996, LB=1133, matches=80, still to save=3
# 197: saved episode #19437649
# 198: saved episode #19435563
# 199: saved episode #19432181
#
# submission=19681376, LB=1132, matches=34, still to save=1
# 200: saved episode #19431190
#
# submission=19519164, LB=1130, matches=83, still to save=3
# 201: saved episode #19439607
# 202: saved episode #19436627
# 203: saved episode #19432614
#
# submission=19691159, LB=1129, matches=41, still to save=3
# 204: saved episode #19439668
# 205: saved episode #19436214
# 206: saved episode #19430708
#
# submission=19722649, LB=1129, matches=22, still to save=22
# 207: saved episode #19439791
# 208: saved episode #19437384
# 209: saved episode #19437095
# 210: saved episode #19435227
# 211: saved episode #19434598
# 212: saved episode #19432227
# 213: saved episode #19430672
# 214: saved episode #19429056
# 215: saved episode #19429024
# 216: saved episode #19428990
# 217: saved episode #19428958
# 218: saved episode #19428925
# 219: saved episode #19428893
# 220: saved episode #19428859
# 221: saved episode #19428827
# 222: saved episode #19428795
# 223: saved episode #19428770
# 224: saved episode #19428763
# 225: saved episode #19428731
# 226: saved episode #19428699
# 227: saved episode #19428666
# 228: saved episode #19428588
#
# submission=19471900, LB=1126, matches=100, still to save=3
# 229: saved episode #19432550
# 230: saved episode #19431198
# 231: saved episode #19430583
#
# submission=19469841, LB=1126, matches=103, still to save=3
# 232: saved episode #19438461
# 233: saved episode #19435124
# 234: saved episode #19431546
#
# submission=19514384, LB=1125, matches=74, still to save=3
# 235: saved episode #19437590
# 236: saved episode #19433680
# 237: saved episode #19430125
#
# submission=19719678, LB=1124, matches=24, still to save=5
# 238: saved episode #19439793
# 239: saved episode #19437056
# 240: saved episode #19436280
# 241: saved episode #19433383
# 242: saved episode #19433254
#
# submission=19705803, LB=1123, matches=29, still to save=3
# 243: saved episode #19439761
# 244: saved episode #19437823
# 245: saved episode #19434755
#
# submission=19476680, LB=1121, matches=82, still to save=3
# 246: saved episode #19438018
# 247: saved episode #19433178
# 248: saved episode #19431805
#
# submission=19483589, LB=1120, matches=94, still to save=1
# 249: saved episode #19437868
#
# submission=19635284, LB=1120, matches=48, still to save=2
# 250: saved episode #19436408
# 251: saved episode #19432070
#
# submission=19732650, LB=1120, matches=18, still to save=16
# 252: saved episode #19440693
# 253: saved episode #19439131
# 254: saved episode #19438337
# 255: saved episode #19438150
# 256: saved episode #19438117
# 257: saved episode #19438084
# 258: saved episode #19438051
# 259: saved episode #19437985
# 260: saved episode #19437951
# 261: saved episode #19437915
# 262: saved episode #19437882
# 263: saved episode #19437848
# 264: saved episode #19437814
# 265: saved episode #19437781
# 266: saved episode #19437748
# 267: saved episode #19437702
#
# submission=19654223, LB=1119, matches=44, still to save=4
# 268: saved episode #19440770
# 269: saved episode #19439167
# 270: saved episode #19434783
# 271: saved episode #19433985
#
# submission=19613348, LB=1119, matches=57, still to save=2
# 272: saved episode #19435262
# 273: saved episode #19432184
#
# submission=19723608, LB=1118, matches=21, still to save=17
# 274: saved episode #19440998
# 275: saved episode #19437561
# 276: saved episode #19433614
# 277: saved episode #19431747
# 278: saved episode #19429967
# 279: saved episode #19429934
# 280: saved episode #19429900
# 281: saved episode #19429869
# 282: saved episode #19429837
# 283: saved episode #19429803
# 284: saved episode #19429771
# 285: saved episode #19429736
# 286: saved episode #19429701
# 287: saved episode #19429664
# 288: saved episode #19429629
# 289: saved episode #19429589
# 290: saved episode #19429574
#
# submission=19703409, LB=1117, matches=31, still to save=4
# 291: saved episode #19439833
# 292: saved episode #19437144
# 293: saved episode #19435593
# 294: saved episode #19432313
#
# submission=19498585, LB=1115, matches=100, still to save=3
# 295: saved episode #19441380
# 296: saved episode #19440408
# 297: saved episode #19437701
#
# submission=19718116, LB=1113, matches=24, still to save=19
# 298: saved episode #19431678
# 299: saved episode #19429461
# 300: saved episode #19427753
# 301: saved episode #19426035
# 302: saved episode #19424706
# 303: saved episode #19424674
# 304: saved episode #19424642
# 305: saved episode #19424608
# 306: saved episode #19424575
# 307: saved episode #19424543
# 308: saved episode #19424510
# 309: saved episode #19424476
# 310: saved episode #19424443
# 311: saved episode #19424410
# 312: saved episode #19424377
# 313: saved episode #19424343
# 314: saved episode #19424310
# 315: saved episode #19424277
# 316: saved episode #19424232
#
# submission=19537563, LB=1112, matches=74, still to save=3
# 317: saved episode #19438998
# 318: saved episode #19432282
# 319: saved episode #19431702
#
# submission=19633549, LB=1111, matches=53, still to save=4
# 320: saved episode #19437326
# 321: saved episode #19437094
# 322: saved episode #19433283
# 323: saved episode #19430064
#
# submission=19723449, LB=1110, matches=22, still to save=21
# 324: saved episode #19440562
# 325: saved episode #19438224
# 326: saved episode #19435465
# 327: saved episode #19434654
# 328: saved episode #19432226
# 329: saved episode #19430709
# 330: saved episode #19430229
# 331: saved episode #19429935
# 332: saved episode #19429901
# 333: saved episode #19429870
# 334: saved episode #19429838
# 335: saved episode #19429804
# 336: saved episode #19429772
# 337: saved episode #19429738
# 338: saved episode #19429702
# 339: saved episode #19429665
# 340: saved episode #19429630
# 341: saved episode #19429590
# 342: saved episode #19429552
# 343: saved episode #19429518
# 344: saved episode #19429467
#
# submission=19458246, LB=1110, matches=96, still to save=4
# 345: saved episode #19440198
# 346: saved episode #19436423
# 347: saved episode #19432418
# 348: saved episode #19431804
#
# submission=19690396, LB=1109, matches=37, still to save=35
# 349: saved episode #19441057
# 350: saved episode #19437889
# 351: saved episode #19435360
# 352: saved episode #19431519
# 353: saved episode #19430323
# 354: saved episode #19426778
# 355: saved episode #19424653
# 356: saved episode #19424419
# 357: saved episode #19424095
# 358: saved episode #19421055
# 359: saved episode #19418075
# 360: saved episode #19416513
# 361: saved episode #19413820
# 362: saved episode #19412238
# 363: saved episode #19409779
# 364: saved episode #19407472
# 365: saved episode #19360572
# 366: saved episode #19356438
# 367: saved episode #19348840
# 368: saved episode #19304021
# 369: saved episode #19284029
# 370: saved episode #19279195
# 371: saved episode #19278503
# 372: saved episode #19277814
# 373: saved episode #19277124
# 374: saved episode #19276433
# 375: saved episode #19275742
# 376: saved episode #19275053
# 377: saved episode #19274364
# 378: saved episode #19273675
# 379: saved episode #19272986
# 380: saved episode #19272295
# 381: saved episode #19271606
# 382: saved episode #19270917
# 383: saved episode #19269256
#
# submission=19705401, LB=1109, matches=30, still to save=2
# 384: saved episode #19438488
# 385: saved episode #19431620
#
# submission=19480854, LB=1108, matches=126, still to save=2
# 386: saved episode #19435776
# 387: saved episode #19433088
#
# submission=19614537, LB=1107, matches=72, still to save=4
# 388: saved episode #19438832
# 389: saved episode #19436886
# 390: saved episode #19435692
# 391: saved episode #19432846
#
# submission=19715073, LB=1106, matches=26, still to save=22
# 392: saved episode #19440959
# 393: saved episode #19438459
# 394: saved episode #19433012
# 395: saved episode #19431380
# 396: saved episode #19428706
# 397: saved episode #19427636
# 398: saved episode #19426155
# 399: saved episode #19424229
# 400: saved episode #19422820
# 401: saved episode #19422160
# 402: saved episode #19421674
# 403: saved episode #19421608
# 404: saved episode #19421575
# 405: saved episode #19421538
# 406: saved episode #19421498
# 407: saved episode #19421466
# 408: saved episode #19421433
# 409: saved episode #19421397
# 410: saved episode #19421363
# 411: saved episode #19421331
# 412: saved episode #19421298
# 413: saved episode #19421284
#
# submission=19469817, LB=1105, matches=110, still to save=3
# 414: saved episode #19440958
# 415: saved episode #19437969
# 416: saved episode #19430067
#
# submission=19498640, LB=1105, matches=109, still to save=4
# 417: saved episode #19439526
# 418: saved episode #19435704
# 419: saved episode #19435491
# 420: saved episode #19431507
#
# submission=19718929, LB=1104, matches=23, still to save=22
# 421: saved episode #19440035
# 422: saved episode #19437454
# 423: saved episode #19434665
# 424: saved episode #19433372
# 425: saved episode #19433119
# 426: saved episode #19428084
# 427: saved episode #19427042
# 428: saved episode #19426428
# 429: saved episode #19425396
# 430: saved episode #19425361
# 431: saved episode #19425328
# 432: saved episode #19425297
# 433: saved episode #19425263
# 434: saved episode #19425231
# 435: saved episode #19425197
# 436: saved episode #19425167
# 437: saved episode #19425134
# 438: saved episode #19425101
# 439: saved episode #19425066
# 440: saved episode #19425029
# 441: saved episode #19425028
# 442: saved episode #19424980
#
# submission=19723513, LB=1103, matches=20, still to save=18
# 443: saved episode #19439566
# 444: saved episode #19437353
# 445: saved episode #19434992
# 446: saved episode #19432554
# 447: saved episode #19431444
# 448: saved episode #19429964
# 449: saved episode #19429932
# 450: saved episode #19429902
# 451: saved episode #19429868
# 452: saved episode #19429835
# 453: saved episode #19429801
# 454: saved episode #19429769
# 455: saved episode #19429737
# 456: saved episode #19429700
# 457: saved episode #19429662
# 458: saved episode #19429627
# 459: saved episode #19429587
# 460: saved episode #19429505
#
# submission=19701978, LB=1102, matches=34, still to save=1
# 461: saved episode #19440864
#
# submission=19699440, LB=1102, matches=33, still to save=27
# 462: saved episode #19439137
# 463: saved episode #19436283
# 464: saved episode #19433116
# 465: saved episode #19428219
# 466: saved episode #19426682
# 467: saved episode #19424060
# 468: saved episode #19422709
# 469: saved episode #19419876
# 470: saved episode #19417296
# 471: saved episode #19414993
# 472: saved episode #19412998
# 473: saved episode #19410946
# 474: saved episode #19410424
# 475: saved episode #19409271
# 476: saved episode #19408228
# 477: saved episode #19407227
# 478: saved episode #19407171
# 479: saved episode #19407036
# 480: saved episode #19407016
# 481: saved episode #19406851
# 482: saved episode #19406809
# 483: saved episode #19406779
# 484: saved episode #19406089
# 485: saved episode #19405398
# 486: saved episode #19404700
# 487: saved episode #19404699
# 488: saved episode #19403333
#
# submission=19590854, LB=1102, matches=59, still to save=3
# 489: saved episode #19440528
# 490: saved episode #19432915
# 491: saved episode #19431188
#
# submission=19559130, LB=1102, matches=84, still to save=3
# 492: saved episode #19438905
# 493: saved episode #19435623
# 494: saved episode #19433442
#
# submission=19614085, LB=1102, matches=53, still to save=3
# 495: saved episode #19437787
# 496: saved episode #19434534
# 497: saved episode #19432190
#
# submission=19517806, LB=1102, matches=106, still to save=3
# 498: saved episode #19436382
# 499: saved episode #19434693
# 500: saved episode #19430611
#
# submission=19690963, LB=1101, matches=40, still to save=4
# 501: saved episode #19439507
# 502: saved episode #19436924
# 503: saved episode #19434929
# 504: saved episode #19431218
#
# submission=19556071, LB=1100, matches=74, still to save=3
