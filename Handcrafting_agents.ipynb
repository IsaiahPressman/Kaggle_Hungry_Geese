# %%
from kaggle_environments import make
env = make("hungry_geese", debug = True)
# Out:
# Loading environment football failed: No module named 'gfootball'

# %%
agent_path = 'handcrafted_agents/a_star_v1.3_greedy.py'
# agent_path = 'handcrafted_agents/public/boilergoose.py'

env.reset()
# env.run([agent_path, agent_path])
env.run([agent_path, agent_path, agent_path, agent_path])
env.render(mode="ipython", width=800, height=700)
# Out:
# Depth: 2
# Depth: 8
# Depth: 3
# Depth: 7
# Depth: 7
# Depth: 2
# Depth: 2
# Depth: 6
# Depth: 2
# Depth: 8
# Depth: 3
# Depth: 7
# Depth: 7
# Depth: 2
# Depth: 2
# Depth: 6
# Depth: 2
# Remaining overage time: 60.00
# Depth: 2
# Depth: 8
# Depth: 3
# Depth: 7
# Depth: 7
# Depth: 2
# Depth: 2
# Depth: 6
# Depth: 2
# Depth: 8
# Depth: 3
# Depth: 7
# Depth: 7
# Depth: 2
# Depth: 2
# Depth: 6
# Depth: 3
# Remaining overage time: 60.00
# Depth: 2
# Depth: 8
# Depth: 3
# Depth: 7
# Depth: 7
# Depth: 2
# Depth: 2
# Depth: 6
# Depth: 2
# Depth: 8
# Depth: 3
# Depth: 7
# Depth: 7
# Depth: 2
# Depth: 2
# Depth: 6
# Depth: 2
# Remaining overage time: 60.00
# Depth: 2
# Depth: 8
# Depth: 3
# Depth: 7
# Depth: 7
# Depth: 2
# Depth: 2
# Depth: 6
# Depth: 2
# Depth: 8
# Depth: 3
# Depth: 7
# Depth: 7
# Depth: 2
# Depth: 2
# Depth: 6
# Depth: 2
# Remaining overage time: 60.00
# Depth: 1
# Depth: 7
# Depth: 2
# Depth: 6
# Depth: 7
# Depth: 1
# Depth: 1
# Depth: 5
# Depth: 1
# Depth: 7
# Depth: 2
# ...
